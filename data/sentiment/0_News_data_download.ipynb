# %%
import pandas as pd
import numpy as np
import OpenBlender
import json

# %%
import datetime

# %%
datetime.date(2020,12,31)
# Out:
# datetime.date(2021, 1, 1)

# %%
datetime.date(2022,7,1)
# Out:
# datetime.date(2022, 7, 1)

# %%
format = '%Y-%m-%d %H:%M:%S'
timezone = 'GMT'
unitDT = OpenBlender.dateToUnix([str(datetime.datetime(2020,12,31,0,0,0)),str(datetime.datetime(2022,7,1,0,0,0))], 
                                           date_format = format, 
                                           timezone = timezone)
token = '62ef533b951629119f0fea45R5ljEQ2lrm17YdGjrl8tfiI6TmHCIr'

# %%
search_keyword = 'cryptocurrency news'

# %%
OpenBlender.searchTimeBlends(token,
                             unitDT,
                             search_keyword)
# Out:
# [{'name': 'Breitbart Business News Headlines',
#   'url': 'https://www.openblender.io/#/dataset/explore/5d57170a9516293a12ad4f36',
#   'id_dataset': '5d57170a9516293a12ad4f36',
#   'features': ['headline', 'publisher', 'timestamp', 'title', 'url'],
#   'num_observations': 6075,
#   'intersection': 100,
#   'description': 'Breitbart Business News Headlines daily headlines'},
#  {'name': 'Breitbart Entertainment News',
#   'url': 'https://www.openblender.io/#/dataset/explore/5d57177b9516293a12ad4f38',
#   'id_dataset': '5d57177b9516293a12ad4f38',
#   'features': ['headline', 'publisher', 'timestamp', 'title', 'url'],
#   'num_observations': 7002,
#   'intersection': 100,
#   'description': 'Breitbart Entertainment News daily headlines'},
#  {'name': 'Reuters Science and Technology News',
#   'url': 'https://www.openblender.io/#/dataset/explore/5d5717e29516293a13832034',
#   'id_dataset': '5d5717e29516293a13832034',
# ...
